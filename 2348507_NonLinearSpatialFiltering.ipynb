# %% [markdown]
# <a href="https://colab.research.google.com/github/badrinarayanan02/Computer-Vision/blob/main/2348507_NonLinearSpatialFiltering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Non-Linear Spatial Filtering**

# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Function to perform maximum filter

# %%
def maxFilter(image, kernel_size):
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    return cv2.dilate(image, kernel, iterations=1)

# %% [markdown]
# Function to perform minimum filter

# %%
def minFilter(image, kernel_size):
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    return cv2.erode(image, kernel, iterations=1)

# %% [markdown]
# Function to perform median filter

# %%
def medianFilter(image, kernel_size):
    return cv2.medianBlur(image, kernel_size)

# %% [markdown]
# Function to perform bilateral filter

# %%
def bilateralFilter(image, d, sigmaColor, sigmaSpace):
    return cv2.bilateralFilter(image, d, sigmaColor, sigmaSpace)

# %% [markdown]
# Loading the Image

# %%
img = cv2.imread('/content/cuteAnil.jpg')
img
# Out:
# array([[[ 2, 20, 27],
#         [ 2, 20, 27],
#         [ 2, 20, 27],
#         ...,
#         [ 3, 53, 53],
#         [ 3, 53, 53],
#         [ 3, 53, 53]],
#
#        [[ 2, 20, 27],
#         [ 2, 20, 27],
#         [ 2, 20, 27],
#         ...,
#         [ 2, 52, 52],
#         [ 2, 52, 52],
#         [ 2, 52, 52]],
#
#        [[ 2, 20, 27],
#         [ 2, 20, 27],
#         [ 2, 20, 27],
#         ...,
#         [ 2, 50, 51],
#         [ 3, 51, 52],
#         [ 3, 51, 52]],
#
#        ...,
#
#        [[ 1, 18, 21],
#         [ 2, 19, 22],
#         [ 0, 19, 24],
#         ...,
#         [ 4, 36, 42],
#         [ 5, 37, 43],
#         [ 3, 37, 43]],
#
#        [[ 1, 18, 21],
#         [ 1, 18, 21],
#         [ 0, 19, 24],
#         ...,
#         [ 1, 33, 39],
#         [ 3, 35, 41],
#         [ 1, 35, 41]],
#
#        [[ 0, 17, 20],
#         [ 1, 18, 21],
#         [ 1, 20, 25],
#         ...,
#         [ 0, 32, 38],
#         [ 2, 34, 40],
#         [ 1, 35, 41]]], dtype=uint8)

# %% [markdown]
# Applying user defined functions

# %%
max_filtered = maxFilter(img, 5)
min_filtered = minFilter(img, 5)
median_filtered = medianFilter(img, 5)
bilateral_filtered = bilateralFilter(img, 9, 75, 75)

# %%
cv2_imshow(img)
cv2_imshow(max_filtered)
cv2_imshow(min_filtered)
cv2_imshow(median_filtered)
cv2_imshow(bilateral_filtered)
# Out:
# <PIL.Image.Image image mode=RGB size=829x580>
# <PIL.Image.Image image mode=RGB size=829x580>
# <PIL.Image.Image image mode=RGB size=829x580>
# <PIL.Image.Image image mode=RGB size=829x580>
# <PIL.Image.Image image mode=RGB size=829x580>

# %% [markdown]
# # **Conclusion**
#
# Thus the task to perform non linear spatial filtering is implemented successfully.
